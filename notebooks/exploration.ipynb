# %%
# Célula 1 – Como executar o pipeline
# -----------------------------------
# Certifique-se de que o pacote está instalado:
#   pip install -e . -r requirements.txt
#
# Para rodar o flow completo:
#   from pipeline.flow import demo_flow
#   demo_flow()
#
# Ou diretamente nesta célula:
# from pipeline.flow import demo_flow
# demo_flow()

# %%
# Célula 2 – Placeholder para gráficos e análises exploratórias
# --------------------------------------------------------------
# Exemplo:
# import pandas as pd
# import matplotlib.pyplot as plt
#
# df = pd.read_parquet('../data/processed/text_entities.parquet')
# df['num_palavras'].plot(kind='bar', title='Palavras por frase')
# plt.tight_layout()
# plt.show()
